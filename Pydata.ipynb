# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd

def load_and_preview_csv(file_path):
    try:
        # Read the CSV file into a DataFrame
        df = pd.read_csv(file_path)
        
        # Print the first 5 rows of the DataFrame
        print(df.head())
        
    except FileNotFoundError:
        print(f"Error: The file at {file_path} was not found.")
    except pd.errors.EmptyDataError:
        print("Error: The file is empty.")
    except pd.errors.ParserError:
        print("Error: There was a parsing error with the file.")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")

# Provide the file path as a string
file_path = r"C:\Users\Simon\Documents\Pydata\2016.csv"

# Call the function
load_and_preview_csv(file_path)
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
# 3       Norway  Western Europe               4            7.498
# 4      Finland  Western Europe               5            7.413
#
#    Lower Confidence Interval Upper Confidence Interval  \
# 0                      7.460                     7.592
# 1                      7.428                      7.59
# 2                      7.333                     7.669
# 3                      7.421                     7.575
# 4                      7.351                     7.475
#
#   Economy (GDP per Capita)   Family Health (Life Expectancy)  Freedom  \
# 0                  1.44178  1.16374                  0.79504  0.57941
# 1                  1.52733  1.14524                  0.86303  0.58557
# ...

# %%
import pandas as pd
import numpy as np

def handle_missing_values(df):
    # Identify columns with missing values
    missing_value_columns = df.columns[df.isnull().any()].tolist()
    if missing_value_columns:
        print("Columns with missing values:", missing_value_columns)
    else:
        print("No columns with missing values found.")

    # Replace missing values with the mean of the column
    for column in missing_value_columns:
        if df[column].dtype in [np.float64, np.int64]:  # Ensure the column is numeric
            mean_value = df[column].mean()
            df[column].fillna(mean_value, inplace=True)
            print(f"Replaced missing values in '{column}' with mean value: {mean_value}")
        else:
            print(f"Skipping non-numeric column '{column}' for mean replacement.")

    return df

# %%
import pandas as pd
import numpy as np

def handle_missing_values(df):
    # Convert placeholders to NaN for uniformity
    df.replace(["", " ", "N/A", "NA", "null", "None"], np.nan, inplace=True)

    # Identify columns with missing values
    missing_value_columns = df.columns[df.isnull().any()].tolist()
    if missing_value_columns:
        print("Columns with missing values:", missing_value_columns)
    else:
        print("No columns with missing values found.")

    # Replace missing values with the mean of the column
    for column in missing_value_columns:
        if pd.api.types.is_numeric_dtype(df[column]):  # Check if the column is numeric
            mean_value = df[column].mean()
            df[column].fillna(mean_value, inplace=True)
            print(f"Replaced missing values in '{column}' with mean value: {mean_value}")
        else:
            print(f"Skipping non-numeric column '{column}' for mean replacement.")

    return df

# %%
# Example DataFrame with various types of missing value representations
data = {
    'A': [1, 2, None, 4],
    'B': [5, 'N/A', '', 8],
    'C': ['x', 'y', 'z', None]
}
df = pd.DataFrame(data)

# Handle missing values
df = handle_missing_values(df)

# Verify the results
print(df)
# Out:
# Columns with missing values: ['A', 'B', 'C']
# Replaced missing values in 'A' with mean value: 2.3333333333333335
# Replaced missing values in 'B' with mean value: 6.5
# Skipping non-numeric column 'C' for mean replacement.
#           A    B     C
# 0  1.000000  5.0     x
# 1  2.000000  6.5     y
# 2  2.333333  6.5     z
# 3  4.000000  8.0  None

# %%
# Reload the data to avoid modified DataFrame
df = pd.read_csv(r"C:\Users\Simon\Documents\Pydata\2016.csv")

# Display a few rows
print(df.head(15))

# Check for missing values column-wise
print(df.isnull().sum())

# Look for other potential placeholders for missing values
print(df.replace(["", " ", "N/A", "NA", "null", "None"], np.nan).isnull().sum())
# Out:
#           Country                           Region  Happiness Rank  \
# 0         Denmark                   Western Europe               1
# 1     Switzerland                   Western Europe               2
# 2         Iceland                   Western Europe               3
# 3          Norway                   Western Europe               4
# 4         Finland                   Western Europe               5
# 5          Canada                    North America               6
# 6     Netherlands                   Western Europe               7
# 7     New Zealand        Australia and New Zealand               8
# 8       Australia        Australia and New Zealand               9
# 9          Sweden                   Western Europe              10
# 10         Israel  Middle East and Northern Africa              11
# 11        Austria                   Western Europe              12
# 12  United States                    North America              13
# ...

# %%
# Specify additional placeholders during data loading
df = pd.read_csv(r"C:\Users\Simon\Documents\Pydata\2016.csv", na_values=["", " ", "N/A", "NA", "null", "None", "-", "?"])

# %%
df = handle_missing_values(df)

# Verify results
print(df.head())
print(df.isnull().sum())
# Out:
# Columns with missing values: ['Lower Confidence Interval', 'Upper Confidence Interval', 'Economy (GDP per Capita)', 'Health (Life Expectancy)', 'Freedom']
# Replaced missing values in 'Lower Confidence Interval' with mean value: 5.268640522875817
# Replaced missing values in 'Upper Confidence Interval' with mean value: 5.472753246753247
# Replaced missing values in 'Economy (GDP per Capita)' with mean value: 0.9517720645161286
# Replaced missing values in 'Health (Life Expectancy)' with mean value: 0.5533422727272724
# Replaced missing values in 'Freedom' with mean value: 0.3709994871794871
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
# 3       Norway  Western Europe               4            7.498
# 4      Finland  Western Europe               5            7.413
# ...
